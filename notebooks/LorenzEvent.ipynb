# %% [markdown]
# # Explore an interesting event in the data
#
# ## Import:

# %%
# !pip install -e ..
import nextbike
import folium
import numpy as np
from folium.plugins import HeatMap, HeatMapWithTime
# Out:
# Obtaining file:///C:/Users/loren/Documents/GitHub/PDS_Project
# Requirement already satisfied: pandas in h:\python\envs\pds_project\lib\site-packages (from PDS-Project==0.0.1.dev13) (1.0.3)
# Requirement already satisfied: scikit-learn in h:\python\envs\pds_project\lib\site-packages (from PDS-Project==0.0.1.dev13) (0.22.2.post1)
# Requirement already satisfied: click in h:\python\envs\pds_project\lib\site-packages (from PDS-Project==0.0.1.dev13) (7.1.1)
# Requirement already satisfied: folium in h:\python\envs\pds_project\lib\site-packages (from PDS-Project==0.0.1.dev13) (0.10.1)
# Requirement already satisfied: numpy>=1.13.3 in h:\python\envs\pds_project\lib\site-packages (from pandas->PDS-Project==0.0.1.dev13) (1.18.3)
# Requirement already satisfied: pytz>=2017.2 in h:\python\envs\pds_project\lib\site-packages (from pandas->PDS-Project==0.0.1.dev13) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in h:\python\envs\pds_project\lib\site-packages (from pandas->PDS-Project==0.0.1.dev13) (2.8.1)
# Requirement already satisfied: scipy>=0.17.0 in h:\python\envs\pds_project\lib\site-packages (from scikit-learn->PDS-Project==0.0.1.dev13) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in h:\python\envs\pds_project\lib\site-packages (from scikit-learn->PDS-Project==0.0.1.dev13) (0.14.1)
# Requirement already satisfied: branca>=0.3.0 in h:\python\envs\pds_project\lib\site-packages (from folium->PDS-Project==0.0.1.dev13) (0.4.1)
# Requirement already satisfied: requests in h:\python\envs\pds_project\lib\site-packages (from folium->PDS-Project==0.0.1.dev13) (2.23.0)
# Requirement already satisfied: jinja2>=2.9 in h:\python\envs\pds_project\lib\site-packages (from folium->PDS-Project==0.0.1.dev13) (2.11.1)
# Requirement already satisfied: six>=1.5 in h:\python\envs\pds_project\lib\site-packages (from python-dateutil>=2.6.1->pandas->PDS-Project==0.0.1.dev13) (1.14.0)
# Requirement already satisfied: idna<3,>=2.5 in h:\python\envs\pds_project\lib\site-packages (from requests->folium->PDS-Project==0.0.1.dev13) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in h:\python\envs\pds_project\lib\site-packages (from requests->folium->PDS-Project==0.0.1.dev13) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in h:\python\envs\pds_project\lib\site-packages (from requests->folium->PDS-Project==0.0.1.dev13) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in h:\python\envs\pds_project\lib\site-packages (from requests->folium->PDS-Project==0.0.1.dev13) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in h:\python\envs\pds_project\lib\site-packages (from jinja2>=2.9->folium->PDS-Project==0.0.1.dev13) (1.1.1)
# Installing collected packages: PDS-Project
#   Attempting uninstall: PDS-Project
#     Found existing installation: PDS-Project 0.0.1.dev13
#     Uninstalling PDS-Project-0.0.1.dev13:
#       Successfully uninstalled PDS-Project-0.0.1.dev13
#   Running setup.py develop for PDS-Project
# Successfully installed PDS-Project

# %% [markdown]
# ## Read the data:

# %%
dfRaw = nextbike.io.read_file()

# %%
dfStationBikeNumber = nextbike.io.preprocessStationData(dfRaw)
dfStationBikeNumber = nextbike.io.createBikeNumberPerStationIndex(dfStationBikeNumber)
dfTrips = nextbike.io.preprocessData(dfRaw)
dfStations = nextbike.io.createStations(dfTrips)
dfTrips = nextbike.io.createTrips(dfTrips)
dfStations
# Out:
# Error at lines:
# 128324
# 128580
# 128674
# 128824
# 128860
# 129114
# 129340
# 129513
# 130326
# 648905
# 649161
# 649255
# 649405
# 649441
# 649695
# 649921
# 650094
# 650907
# 1169486
# 1169742
# 1169836
# 1169986
# 1170022
# 1170276
# 1170502
# 1170675
# 1171488
#                                                     pName       pLat     pLong
# pNumber
# 0                                        no fixed station        NaN       NaN
# 5140                                             Anatomie  50.816058  8.772242
# 5141                            Ketzerbach/Zwischenhausen  50.813950  8.766160
# 5142                                       Friedrichplatz  50.803270  8.764060
# 5143               Interkulturelle Gaerten/ Am Richtsberg  50.794700  8.772230
# 5144                        Carolinenhaus/Elisabethkirche  50.814655  8.771212
# 5145                         Neue Universitaetsbibliothek  50.813691  8.770734
# 5146                          Cafe Traume/Affoellerwiesen  50.820220  8.771030
# 5147                                      Am Schuelerpark  50.812779  8.780602
# 5150                   Alte Kasseler Strasse/Jaegertunnel  50.822927  8.774681
# 5151                         Am Krekel/Stadtwerke Marburg  50.789508  8.756438
# 5152                    Am Plan/Wirtschaftswissenschaften  50.807894  8.766971
# 5153                                An den Siechengaerten  50.805809  8.782821
# 5154                 Ersatz-Station / August-Bebel-Platz   50.781000  8.765460
# 5155                               Biegenstrasse/Cineplex  50.808852  8.773134
# 5156                        Biegenstrasse/Volkshochschule  50.813203  8.775948
# 5157                                       Brunnenstrasse  50.816601  8.751507
# 5158                            Elisabeth-Blochmann-Platz  50.808057  8.775308
# 5159                      Frankfurter Strasse/Psychologie  50.804522  8.770358
# 5160     Friedrich-Ebert-Strasse/ Christian-Wolff-Haeuser  50.785589  8.779437
# 5162                          Frankfurter Strasse/Theater  50.798841  8.762144
# 5163                               Georg-Gassmann-Stadion  50.798656  8.752965
# 5164                                     Ginseldorfer Weg  50.827921  8.775086
# 5165                                         Hauptbahnhof  50.819957  8.773736
# 5166                                              Audimax  50.810971  8.774241
# 5167                              Marbacher Weg/Pharmazie  50.813187  8.763264
# 5168                                       Ortenbergplatz  50.816653  8.781166
# 5169                             Philosophische Fakultaet  50.809813  8.779429
# 5171                                              Aquamar  50.801337  8.773266
# 5172                                           Stadtbuero  50.790362  8.766947
# 5173                                          Suedbahnhof  50.795224  8.763266
# 5174                                Suedbahnhof Westseite  50.795270  8.762049
# 5175                                 Universitaetsstadion  50.803751  8.774697
# 5176                 Universitaetsstrasse/Bibliothek Jura  50.807063  8.769918
# 5177                                   Wehrda Buergerhaus  50.836178  8.756796
# 5178                                        Wilhelmsplatz  50.804725  8.759248

# %% [markdown]
# ## Visualization:
# ### Creating the underlying map and marking the stations

# %%
m = folium.Map(location=[50.8008, 8.7667], zoom_start=13, tiles='Stamen Toner')

for index, row in dfStations.iloc[1:].iterrows():     
        folium.CircleMarker(
            location=[row['pLat'], row['pLong']],
            popup=row['pName'],
            color='black',
            fill=True,
            fill_color='#3186cc'
        ).add_to(m)

f = folium.FeatureGroup(name='Start locations')
f2 = folium.FeatureGroup(name='End locations')
f3 = folium.FeatureGroup(name='Mixed weights')
f4 = folium.FeatureGroup(name='Mixed weights2')

# %% [markdown]
# ### Creating the heatmap

# %%
movingData = dfTrips.loc[dfTrips['sTime'].dt.date == np.datetime64('2019-08-01')]
heatData = np.c_[movingData[['sLat','sLong']].values.tolist(),np.ones(len(movingData['eLat']))*(1)].tolist()
heatData2 = np.c_[movingData[['eLat','eLong']].values.tolist(),np.ones(len(movingData['eLat']))*(1)].tolist()
heatData3 = np.r_[np.c_[movingData[['sLat','sLong']].values.tolist(),np.ones(len(movingData['eLat']))*(1)].tolist(),np.c_[movingData[['eLat','eLong']].values.tolist(),np.ones(len(movingData['eLat']))*(-1)].tolist()].tolist()
heatData4 = np.r_[np.c_[movingData[['sLat','sLong']].values.tolist(),np.ones(len(movingData['eLat']))*(-1)].tolist(),np.c_[movingData[['eLat','eLong']].values.tolist(),np.ones(len(movingData['eLat']))*(1)].tolist()].tolist()
#heatData3

# %%
HeatMap(heatData, min_opacity=0.5,max_val=50,name='Start',radius=30).add_to(f)
HeatMap(heatData2, min_opacity=0.5,max_val=50,name='Start',radius=30).add_to(f2)
HeatMap(heatData3, min_opacity=0.5,max_val=50,name='Start',radius=30).add_to(f3)
HeatMap(heatData4, min_opacity=0.5,max_val=50,name='Start',radius=30).add_to(f4)

f.add_to(m)
f2.add_to(m)
f3.add_to(m)
f4.add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
heatData3 == heatData4
# Out:
# False

# %%
# timeframe is the amount of hours around the cutTime and date that are rendered. Date example '2019-08-01'
def createSplitHeatmap(dfTrips,dfStations,date,cutTime = '12:00',timeframe=12):
    # Prepare the data
    movingDataS = dfTrips.loc[(dfTrips['sTime'] >= (np.datetime64(date) - np.timedelta64(timeframe,'h'))) & (dfTrips['sTime'] <= (np.datetime64(date)))]
    movingDataE = dfTrips.loc[(dfTrips['sTime'] >= (np.datetime64(date) )) & (dfTrips['sTime'] <= (np.datetime64(date) + np.timedelta64(timeframe,'h')))]
    

    heatDataS = np.c_[movingDataS[['sLat','sLong']].values.tolist(),np.ones(len(movingDataS['eLat']))*(1)].tolist()
    heatDataE = np.c_[movingDataE[['sLat','sLong']].values.tolist(),np.ones(len(movingDataE['eLat']))*(1)].tolist()
    
    # Create the map
    map = folium.Map(location=[50.8008, 8.7667], zoom_start=13, tiles='Stamen Toner')
    # Add stations as black circle
    for index, row in dfStations.iloc[1:].iterrows():     
        folium.CircleMarker(
            location=[row['pLat'], row['pLong']],
            popup=row['pName'],
            color='black',
            fill=True,
            fill_color='#3186cc'
        ).add_to(m)

    f = folium.FeatureGroup(name='Start locations early')
    f2 = folium.FeatureGroup(name='Start locations later')
    HeatMap(heatDataS, min_opacity=0.5,max_val=50,name='Start',radius=30).add_to(f)
    HeatMap(heatDataE, min_opacity=0.5,max_val=50,name='End',radius=30).add_to(f2)
    f.add_to(m)
    f2.add_to(m)
    return map


map = createSplitHeatmap(dfTrips,dfStations,'2019-05-30 12:00')



def addFeatureGroup():
    return


def addFeatureGroupsToMap():
    return
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-903004972eb7> in <module>
#      30
#      31
# ---> 32 createSplitHeatmap(dfTrips,dfStations,'2019-05-30 12:00')
#      33
#      34
#
# <ipython-input-89-903004972eb7> in createSplitHeatmap(dfTrips, dfStations, date, cutTime, timeframe)
#       2 def createSplitHeatmap(dfTrips,dfStations,date,cutTime = '12:00',timeframe=12):
#       3     # Prepare the data
# ----> 4     movingDataS = dfTrips.loc[(dfTrips['sTime'] >= (np.datetime64(date) - np.timedelta64(time,'h'))) & (dfTrips['sTime'] <= (np.datetime64(date)))]
#       5     movingDataE = dfTrips.loc[(dfTrips['sTime'] >= (np.datetime64(date) )) & (dfTrips['sTime'] <= (np.datetime64(date) + np.timedelta64(time,'h')))]
#       6
#
# NameError: name 'time' is not defined

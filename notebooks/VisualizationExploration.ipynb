# %%
# !pip install -e ..
# Out:
# Obtaining file:///Users/tobiasolbruck/University/PDS/PDS_Project
# Requirement already satisfied: pandas in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from PDS-Project==0.0.1.dev20) (1.0.1)
# Requirement already satisfied: scikit-learn in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from PDS-Project==0.0.1.dev20) (0.22.1)
# Requirement already satisfied: click in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from PDS-Project==0.0.1.dev20) (7.0)
# Requirement already satisfied: geopy in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from PDS-Project==0.0.1.dev20) (1.22.0)
# Requirement already satisfied: folium in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from PDS-Project==0.0.1.dev20) (0.11.0)
# Requirement already satisfied: sklearn in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from PDS-Project==0.0.1.dev20) (0.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from pandas->PDS-Project==0.0.1.dev20) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from pandas->PDS-Project==0.0.1.dev20) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from pandas->PDS-Project==0.0.1.dev20) (2.8.1)
# Requirement already satisfied: joblib>=0.11 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->PDS-Project==0.0.1.dev20) (0.14.1)
# Requirement already satisfied: scipy>=0.17.0 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->PDS-Project==0.0.1.dev20) (1.4.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from geopy->PDS-Project==0.0.1.dev20) (1.50)
# Requirement already satisfied: branca>=0.3.0 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from folium->PDS-Project==0.0.1.dev20) (0.4.1)
# Requirement already satisfied: requests in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from folium->PDS-Project==0.0.1.dev20) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from folium->PDS-Project==0.0.1.dev20) (2.11.1)
# Requirement already satisfied: six>=1.5 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->PDS-Project==0.0.1.dev20) (1.14.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from requests->folium->PDS-Project==0.0.1.dev20) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from requests->folium->PDS-Project==0.0.1.dev20) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from requests->folium->PDS-Project==0.0.1.dev20) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from requests->folium->PDS-Project==0.0.1.dev20) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium->PDS-Project==0.0.1.dev20) (1.1.1)
# Installing collected packages: PDS-Project
#   Attempting uninstall: PDS-Project
#     Found existing installation: PDS-Project 0.0.1.dev20
#     Uninstalling PDS-Project-0.0.1.dev20:
#       Successfully uninstalled PDS-Project-0.0.1.dev20
#   Running setup.py develop for PDS-Project
# Successfully installed PDS-Project

# %%
import nextbike

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import datetime
import time
import numpy as np
import scipy.stats as stats
import math

# %%
start = time.time()
df = nextbike.io.read_file()
df = nextbike.io.preprocessData(df)
df_trips = nextbike.io.createTrips(df)
ende = time.time()
print('{:5.3f}s'.format(ende-start), end='  ')
# Out:
# 349.071s

# %%
start = time.time()
df_trips_cleaned = nextbike.io.drop_outliers(df_trips)
ende = time.time()
print('{:5.3f}s'.format(ende-start), end='  ')
# Out:
# 113.877s

# %%
df_trips_cleaned.head()
# Out:
#    bNumber               sTime               eTime duration     sLong  \
# 0    11169 2019-01-20 01:55:00 2019-01-20 02:06:00 00:11:00  8.763266
# 2    11169 2019-01-20 11:58:00 2019-01-20 12:06:00 00:08:00  8.770358
# 3    11169 2019-01-20 15:12:00 2019-01-20 15:27:00 00:15:00  8.759248
# 4    11169 2019-01-20 15:39:00 2019-01-20 15:42:00 00:03:00  8.774681
# 5    11270 2019-01-20 00:25:00 2019-01-20 00:37:00 00:12:00  8.775948
#
#         sLat     eLong       eLat  weekend  bType  sPlaceNumber  ePlaceNumber  \
# 0  50.795224  8.770358  50.804522     True     15          5173          5159
# 2  50.804522  8.759248  50.804725     True     15          5159          5178
# 3  50.804725  8.774681  50.822927     True     15          5178          5150
# 4  50.822927  8.774681  50.822927     True     15          5150          5150
# 5  50.813203  8.775948  50.813203     True     15          5156          5156
#
#    durationInSec
# 0            660
# 2            480
# 3            900
# 4            180
# 5            720

# %%
dfWeather = nextbike.io.getWeatherData()
dfWeather.head()
# Out:
#                      temperature  precipitation
# date
# 2019-01-01 00:00:00          7.6            0.0
# 2019-01-01 00:10:00          7.3            0.0
# 2019-01-01 00:20:00          7.4            0.0
# 2019-01-01 00:30:00          7.5            0.0
# 2019-01-01 00:40:00          7.6            0.0

# %%
(nextbike.visualization.visualizeNumberOfTrips(df_trips_cleaned)).show()

# %%
(nextbike.visualization.visualizeMeanTripLength(df_trips_cleaned)).show()

# %%
(nextbike.visualization.visualizeStdTripLength(df_trips_cleaned)).show()

# %%
(nextbike.visualization.visualizeTripLengthBoxplots(df_trips_cleaned))
# Out:
# <module 'seaborn' from '/Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages/seaborn/__init__.py'>

# %%
(nextbike.visualization.visualizeDistributionOfTripsPerMonth(df_trips_cleaned))
# Out:
# <module 'matplotlib.pyplot' from '/Users/tobiasolbruck/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
nextbike.visualization.visualizeWeatherData(dfWeather).show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
nextbike.visualization.visualizeNumberOfTripsWithTemperatureAndPrecipitation(dfWeather, df_trips_cleaned)
